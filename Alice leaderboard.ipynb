# %%
A = [1, 2, 2, 1]  
B = set([1, 2, 2, 1])
print("the sum of A is:", sum(A))
print("the sum of B is:", sum(B))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 A = [1, 2, 2, 1]
# ----> 2 B = set([1, 2, 2, 1])
#       3 print("the sum of A is:", sum(A))
#       4 print("the sum of B is:", sum(B))
#
# TypeError: 'set' object is not callable
